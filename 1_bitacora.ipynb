# %% [markdown]
# # 📝 Bitácora kepler-Lab

# %% [markdown]
# 🚀 **[07.03.2026] - [Inicio Kepler🪐]**
#
# - Clonar repositorio ☑️
# *da-sat-02-kepler-limpieza-datos*: https://github.com/Anais-RV/da-sat-02-kepler-limpieza-datos.git
#
# - Creación de mi propio repositorio: ☑️
# *kepler-lab*: https://github.com/ArantxaPuig/kepler-lab.git
#
# - Lectura repositorio Keppler ☑️
#
# - Creación apuntes teoria ☑️
#
# - Prácticas por temática ☑️
